# %% [markdown]
# # Project: BBLF AI Selector v2
# # Section: Optimisation & Simulation Tool
# # Sub Section: During Tourny (Post Rnd 4)

# %% [markdown]
# Goal: Select the optimal starting 12 players prior to the start of the tournament

# %% [markdown]
# Things to add:
# 1. Additional constraints to capture fantasy nuances e.g. captain points, vice captain trick

# %% [markdown]
# # 0. Prerequistes

# %%
# pip install --upgrade pip

# %%
# !pip install mip==1.16rc0
# !pip install mip
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 
from scipy.stats import norm
import joblib
from concurrent.futures import ProcessPoolExecutor
import warnings
warnings.filterwarnings("ignore")

# Import intermediary functions
from Optimisation_Functions import roll_rnd_price_fn, optimise_fn_efp, optimise_fn_sim_fp, optimise_setup_fn

# Set working directory
os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/add_data_created/post_round_4/'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/add_data_created/overall'
py_data_score_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/python_data/scoring'
py_data_score_rnd_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/python_data/scoring/post-round-4/'

# %%
# Optimisation Strategy
opt_strat = 'efp' # Options: 'efp' (new player expected fantasy points appraoch), 'sim' (new player fantasy point distribution approach)
current_rnd = 5 # Current Round of the Tournament
exp_pts_model = 'all' # Options: 'bat_bowl' (batting + bowling model), 'all' (combined model)
efp_budget = 2010600
sim_budget = 1994700

# Constraints
# squad_players = 15 Not required as strategy set to 15 players (following round 1 optimisation strategy)

# For Simulation Optimisation Strategy
conf_int = 0.2
sim_num = 10000

# %% [markdown]
# # 1. New EFP Approach

# %% [markdown]
# # a. Data Extraction

# %%
# New Season Optimisation Strategy (Expected Fantasy Points)
if opt_strat == 'efp':
    
    # Data Extraction 
    # Pull in player price data csv file 
    price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_2026_efp_rnd_4.csv'), low_memory=False)

    # Create Player Role Flags
    price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
    price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 

    team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
    # team_fix_df = team_fix_df[team_fix_df.Round >= current_rnd].dropna()

    # Join team fixture to player price to create a row for each game
    game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")

    # Pull player expected points csv file
    if exp_pts_model == 'bat_bowl':
        efp_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_bat_bowl_model_score_short_pr4.csv'), low_memory=False)
    elif exp_pts_model == 'all':
        efp_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_model_score_short_pr4.csv'), low_memory=False)

    # Join on expected points for each game
    player_df_raw = pd.merge(game_df, efp_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")
    # If pts_type is exp then add fielding points to expected points
    player_df_raw["exp_points"] = np.where((player_df_raw["Role"] == "WK") & (player_df_raw["pts_type"] == "exp"), player_df_raw["exp_pts"] + 11.68,
                                           np.where((player_df_raw["pts_type"] == "exp"), player_df_raw["exp_pts"] + 4.42, player_df_raw["exp_pts"]))
    
    # Drop unnecessary columns
    player_df_raw = player_df_raw[["Name", "Team", "Role", "Price", "Wk_f", "Bat_f", "Bowl_f", "Available", "In_Team", "Round", "opp", "venue", "Home_f", "exp_points"]]
    player_df_raw["weight"] = 1

    # Create game count per player
    player_df_raw["game_num"] = player_df_raw.groupby("Name").cumcount() + 1
    
else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")

# %% [markdown]
# # b. Player price prediction for each round & data prep for optimisation

# %%
if opt_strat == 'efp':
    # Incorporate Player Actual Points into dataframes used for pricing model

    
    # Import Pricing Models
    # Load Model Objects
    price_model_obj_1 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_1_game'))
    price_model_obj_2 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_2_game'))
    price_model_obj_3 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_3_game'))

    # Create rolling round player price dataframes
    player_df_r1, player_df_r2, player_df_r3, player_df_r4, player_df_r5, player_df_r6, player_df_r7, player_df_r8, player_df_r9 = roll_rnd_price_fn(player_df_raw, price_df, current_rnd, price_model_obj_1, price_model_obj_2, price_model_obj_3)

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")

# %% [markdown]
# # c. Optimisation Process (During Tournament Selection) - Starting 12 + 3 Bench Players
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12 + 3 bench player
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,802,500 (As bench costs $79,000)

# %% [markdown]
# ## Optimisation Setup

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    # a. EFP Optimisation Variables Setup
    # points_r1, price_r1, weight_r1, in_team_r1, available_r1, wk_weight_r1, bat_weight_r1, bowl_weight_r1, \
    #     play_cnt_r1, total_player_r1, wk_cnt_r1, total_wk_r1, bat_cnt_r1, total_bat_r1, bowl_cnt_r1, total_bowl_r1, \
    #     budget_r1, total_budget_r1, player_df_r1, cnt_r1, max_player_r1, \
    # points_r2, price_r2, weight_r2, in_team_r2, available_r2, wk_weight_r2, bat_weight_r2, bowl_weight_r2, \
    # play_cnt_r2, total_player_r2, wk_cnt_r2, total_wk_r2, bat_cnt_r2, total_bat_r2, bowl_cnt_r2, total_bowl_r2, \
    # budget_r2, total_budget_r2, team_play_cnt_r2, total_team_player_r2, player_df_r2, cnt_r2, max_player_r2, \
    # points_r3, price_r3, weight_r3, in_team_r3, available_r3, wk_weight_r3, bat_weight_r3, bowl_weight_r3, \
    # play_cnt_r3, total_player_r3, wk_cnt_r3, total_wk_r3, bat_cnt_r3, total_bat_r3, bowl_cnt_r3, total_bowl_r3, \
    # budget_r3, total_budget_r3, team_play_cnt_r3, total_team_player_r3, player_df_r3, cnt_r3, max_player_r3, \
    # points_r4, price_r4, weight_r4, in_team_r4, available_r4, wk_weight_r4, bat_weight_r4, bowl_weight_r4, \
    # play_cnt_r4, total_player_r4, wk_cnt_r4, total_wk_r4, bat_cnt_r4, total_bat_r4, bowl_cnt_r4, total_bowl_r4, \
    # budget_r4, total_budget_r4, team_play_cnt_r4, total_team_player_r4, player_df_r4, cnt_r4, max_player_r4, \
    points_r5, price_r5, weight_r5, in_team_r5, available_r5, wk_weight_r5, bat_weight_r5, bowl_weight_r5, \
    play_cnt_r5, total_player_r5, wk_cnt_r5, total_wk_r5, bat_cnt_r5, total_bat_r5, bowl_cnt_r5, total_bowl_r5, \
    budget_r5, total_budget_r5, team_play_cnt_r5, total_team_player_r5, player_df_r5, cnt_r5, max_player_r5, \
    points_r6, price_r6, weight_r6, in_team_r6, available_r6, wk_weight_r6, bat_weight_r6, bowl_weight_r6, \
    play_cnt_r6, total_player_r6, wk_cnt_r6, total_wk_r6, bat_cnt_r6, total_bat_r6, bowl_cnt_r6, total_bowl_r6, \
    budget_r6, total_budget_r6, team_play_cnt_r6, total_team_player_r6, player_df_r6, cnt_r6, max_player_r6, \
    points_r7, price_r7, weight_r7, in_team_r7, available_r7, wk_weight_r7, bat_weight_r7, bowl_weight_r7, \
    play_cnt_r7, total_player_r7, wk_cnt_r7, total_wk_r7, bat_cnt_r7, total_bat_r7, bowl_cnt_r7, total_bowl_r7, \
    budget_r7, total_budget_r7, team_play_cnt_r7, total_team_player_r7, player_df_r7, cnt_r7, max_player_r7, \
    points_r8, price_r8, weight_r8, in_team_r8, available_r8, wk_weight_r8, bat_weight_r8, bowl_weight_r8, \
    play_cnt_r8, total_player_r8, wk_cnt_r8, total_wk_r8, bat_cnt_r8, total_bat_r8, bowl_cnt_r8, total_bowl_r8, \
    budget_r8, total_budget_r8, team_play_cnt_r8, total_team_player_r8, player_df_r8, cnt_r8, max_player_r8, \
    points_r9, price_r9, weight_r9, in_team_r9, available_r9, wk_weight_r9, bat_weight_r9, bowl_weight_r9, \
    play_cnt_r9, total_player_r9, wk_cnt_r9, total_wk_r9, bat_cnt_r9, total_bat_r9, bowl_cnt_r9, total_bowl_r9, \
    budget_r9, total_budget_r9, team_play_cnt_r9, total_team_player_r9, player_df_r9, cnt_r9, max_player_r9 =  optimise_setup_fn(
        player_df_r5, player_df_r6, player_df_r7, player_df_r8, player_df_r9, efp_budget)

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")

# %% [markdown]
# ## Optimisation Runner

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    sel_player_df, sel_player_df_r5, sel_player_df_r6, sel_player_df_r7,sel_player_df_r8, sel_player_df_r9 = optimise_fn_efp(
        # Round 1
        # points_r1, price_r1, weight_r1, in_team_r1, available_r1, wk_weight_r1, bat_weight_r1, bowl_weight_r1,
        # play_cnt_r1, total_player_r1, wk_cnt_r1, total_wk_r1, bat_cnt_r1, total_bat_r1, bowl_cnt_r1, total_bowl_r1,
        # budget_r1, total_budget_r1, player_df_r1, cnt_r1, max_player_r1,
        # Round 2
        # points_r2, price_r2, weight_r2, in_team_r2, available_r2, wk_weight_r2, bat_weight_r2, bowl_weight_r2,
        # play_cnt_r2, total_player_r2, wk_cnt_r2, total_wk_r2, bat_cnt_r2, total_bat_r2, bowl_cnt_r2, total_bowl_r2,
        # budget_r2, total_budget_r2, team_play_cnt_r2, total_team_player_r2, player_df_r2, cnt_r2, max_player_r2,
        # Round 3
        # points_r3, price_r3, weight_r3, in_team_r3, available_r3, wk_weight_r3, bat_weight_r3, bowl_weight_r3,
        # play_cnt_r3, total_player_r3, wk_cnt_r3, total_wk_r3, bat_cnt_r3, total_bat_r3, bowl_cnt_r3, total_bowl_r3,
        # budget_r3, total_budget_r3, team_play_cnt_r3, total_team_player_r3, player_df_r3, cnt_r3, max_player_r3,
        # Round 4
        # points_r4, price_r4, weight_r4, in_team_r4, available_r4, wk_weight_r4, bat_weight_r4, bowl_weight_r4,
        # play_cnt_r4, total_player_r4, wk_cnt_r4, total_wk_r4, bat_cnt_r4, total_bat_r4, bowl_cnt_r4, total_bowl_r4,
        # budget_r4, total_budget_r4, team_play_cnt_r4, total_team_player_r4, player_df_r4, cnt_r4, max_player_r4,
        # Round 5
        points_r5, price_r5, weight_r5, in_team_r5, available_r5, wk_weight_r5, bat_weight_r5, bowl_weight_r5,
        play_cnt_r5, total_player_r5, wk_cnt_r5, total_wk_r5, bat_cnt_r5, total_bat_r5, bowl_cnt_r5, total_bowl_r5,
        budget_r5, total_budget_r5, team_play_cnt_r5, total_team_player_r5, player_df_r5, cnt_r5, max_player_r5,
        # Round 6
        points_r6, price_r6, weight_r6, in_team_r6, available_r6, wk_weight_r6, bat_weight_r6, bowl_weight_r6,
        play_cnt_r6, total_player_r6, wk_cnt_r6, total_wk_r6, bat_cnt_r6, total_bat_r6, bowl_cnt_r6, total_bowl_r6,
        budget_r6, total_budget_r6, team_play_cnt_r6, total_team_player_r6, player_df_r6, cnt_r6, max_player_r6,
        # Round 7
        points_r7, price_r7, weight_r7, in_team_r7, available_r7, wk_weight_r7, bat_weight_r7, bowl_weight_r7,
        play_cnt_r7, total_player_r7, wk_cnt_r7, total_wk_r7, bat_cnt_r7, total_bat_r7, bowl_cnt_r7, total_bowl_r7,
        budget_r7, total_budget_r7, team_play_cnt_r7, total_team_player_r7, player_df_r7, cnt_r7, max_player_r7,
        # Round 8
        points_r8, price_r8, weight_r8, in_team_r8, available_r8, wk_weight_r8, bat_weight_r8, bowl_weight_r8,
        play_cnt_r8, total_player_r8, wk_cnt_r8, total_wk_r8, bat_cnt_r8, total_bat_r8, bowl_cnt_r8, total_bowl_r8,
        budget_r8, total_budget_r8, team_play_cnt_r8, total_team_player_r8, player_df_r8, cnt_r8, max_player_r8,
        # Round 9
        points_r9, price_r9, weight_r9, in_team_r9, available_r9, wk_weight_r9, bat_weight_r9, bowl_weight_r9,
        play_cnt_r9, total_player_r9, wk_cnt_r9, total_wk_r9, bat_cnt_r9, total_bat_r9, bowl_cnt_r9, total_bowl_r9,
        budget_r9, total_budget_r9, team_play_cnt_r9, total_team_player_r9, player_df_r9, cnt_r9, max_player_r9
    )

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# ----- Optimal Team Selection Summary -----
# ----- Round 5 -----
# Total Expected Points (rnd 5): 1011.0645332336427
# Total Team Cost (rnd 5): 1989500.0
# Captain (rnd 5): Tom Curran
# Bench Player (rnd 5): Aaron Hardie ($122,500.0)
# Current Players Remaining (rnd 5): 12.0
# ----- Round 6 -----
# Total Expected Points (rnd 6): 904.7979682922364
# Total Team Cost (rnd 6): 2080463.634201382
# Captain (rnd 6): Ben Dwarshuis
# Bench Player (rnd 6): Mitch Owen ($116,100.0)
# Current Players Remaining (rnd 6): 11
# ----- Round 7 -----
# Total Expected Points (rnd 7): 1188.531286315918
# Total Team Cost (rnd 7): 2147537.872824805
# Captain (rnd 7): Matthew Short
# Bench Player (rnd 7): Babar Azam ($125,204.68114112747)
# Current Players Remaining (rnd 7): 12
# ----- Round 8 -----
# Total Expected Points (rnd 8): 1052.174825592041
# Total Team Cost (rnd 8): 2122980.054138812
# Captain (rnd 8): Will Sutherland
# Bench Player (rnd 8): Babar Azam ($125,204.68114112747)
# Current Players Remaining (rnd 8): 12
# ----- Round 9 -----
# Total Expected Points (rnd 9): 1020.0813557434083
# Total Team Cost (rnd 9): 2203133.80222842
# Captain (rnd 9): Ben Dwarshuis
# Bench Player (rnd 9): Andrew Tye ($108,763.06759874539)
# Current Players Remaining (rnd 9): 12
# Total Expected Points: 4855.607892456055

# %% [markdown]
# ## Optimisation Results

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    # Display Round-wise Selected Teams
    print("Round 5 Selected Team")
    display(sel_player_df_r5.sort_values(by='exp_rnd_points', ascending=False))

    # Display Traded In Players
    traded_in_r5 = sel_player_df_r5[sel_player_df_r5['In_Team'] == 0]
    print("Round 5 Traded In Players")
    display(traded_in_r5.sort_values(by='exp_rnd_points', ascending=False))

    # Display Traded Out Players
    traded_out_r5 = player_df_r5[player_df_r5['In_Team'] == 1][~player_df_r5['Name'].isin(sel_player_df_r5['Name'])].drop_duplicates(subset=['Name'])
    print("Round 5 Traded Out Players")
    display(traded_out_r5.sort_values(by='exp_rnd_points', ascending=False))

    # Save Optimal Team to CSV
    if exp_pts_model == 'all':
        # sel_player_df.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_rnd_5.csv'), index=False)
        # sel_player_df_r5.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_round_rnd_5.csv'), index=False)
        print("EFP Optimal Team Saved")
    elif exp_pts_model == 'bat_bowl':
        # sel_player_df.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_dual_rnd_5.csv'), index=False)
        # sel_player_df_r5.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_dual_round_rnd_5.csv'), index=False)
        print("EFP Bat + Bowl Optimal Team Saved")
else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Round 5 Selected Team
#                Name  Round     Price                 Team  Wk_f  Bat_f  \
# 10       Tom Curran      5  138000.0      Melbourne Stars   0.0    1.0
# 0     Glenn Maxwell      5  150700.0      Melbourne Stars   0.0    1.0
# 2        Haris Rauf      5  158500.0      Melbourne Stars   0.0    0.0
# 9        Sam Harper      5  129200.0      Melbourne Stars   1.0    1.0
# 8      Peter Siddle      5  138700.0      Melbourne Stars   0.0    0.0
# 4     Matthew Short      5  231500.0    Adelaide Strikers   0.0    1.0
# 3   Jack Wildermuth      5  178100.0        Brisbane Heat   0.0    1.0
# 5        Mitch Owen      5  116100.0    Hobart Hurricanes   0.0    1.0
# 11  Will Sutherland      5  130900.0  Melbourne Renegades   0.0    1.0
# 6      Nathan Ellis      5  133500.0    Hobart Hurricanes   0.0    0.0
# 7   Nathan McAndrew      5   77300.0       Sydney Thunder   0.0    0.0
# 1   Gurinder Sandhu      5  100900.0  Melbourne Renegades   0.0    0.0
# 14   Riley Meredith      5  108000.0    Hobart Hurricanes   0.0    0.0
# 12     Aaron Hardie      5  122500.0      Perth Scorchers   0.0    1.0
# 13   Mahli Beardman      5   75600.0      Perth Scorchers   0.0    0.0
#
#     Bowl_f  Role  weight  Available  In_Team  exp_rnd_points  games_in_round  \
# 10     1.0  ALLR     1.0        1.0      1.0      111.098858             2.0
# 0      1.0  ALLR     1.0        1.0      1.0      102.779964             2.0
# 2      0.0   BWL     1.0        1.0      1.0       99.796726             2.0
# 9      0.0    WK     1.0        1.0      0.0       97.883949             2.0
# 8      0.0   BWL     1.0        1.0      0.0       96.385822             2.0
# 4      1.0  ALLR     1.0        1.0      1.0       71.680132             1.0
# 3      1.0  ALLR     1.0        1.0      1.0       57.084616             1.0
# 5      1.0  ALLR     1.0        1.0      1.0       54.956530             1.0
# 11     1.0  ALLR     1.0        1.0      1.0       54.600775             1.0
# 6      0.0   BWL     1.0        1.0      1.0       52.321531             1.0
# 7      0.0   BWL     1.0        1.0      1.0       51.497267             1.0
# 1      0.0   BWL     1.0        1.0      0.0       49.879507             1.0
# 14     0.0   BWL     1.0        1.0      1.0       49.303369             1.0
# 12     1.0  ALLR     1.0        1.0      1.0       48.620840             1.0
# 13     0.0   BWL     1.0        1.0      1.0       44.249056             1.0
#
#     Is_Bench
# 10         0
# 0          0
# 2          0
# 9          0
# 8          0
# 4          0
# 3          0
# 5          0
# 11         0
# 6          0
# 7          0
# 1          0
# 14         1
# 12         1
# 13         1
# Round 5 Traded In Players
#               Name  Round     Price                 Team  Wk_f  Bat_f  Bowl_f  \
# 9       Sam Harper      5  129200.0      Melbourne Stars   1.0    1.0     0.0
# 8     Peter Siddle      5  138700.0      Melbourne Stars   0.0    0.0     0.0
# 1  Gurinder Sandhu      5  100900.0  Melbourne Renegades   0.0    0.0     0.0
#
#   Role  weight  Available  In_Team  exp_rnd_points  games_in_round  Is_Bench
# 9   WK     1.0        1.0      0.0       97.883949             2.0         0
# 8  BWL     1.0        1.0      0.0       96.385822             2.0         0
# 1  BWL     1.0        1.0      0.0       49.879507             1.0         0
# Round 5 Traded Out Players
#             Name  Round     Price               Team  Wk_f  Bat_f  Bowl_f  \
# 35    Finn Allen      5  120400.0    Perth Scorchers   1.0    1.0     0.0
# 61    Joel Paris      5  117400.0    Perth Scorchers   0.0    0.0     0.0
# 89  Matthew Wade      5   95100.0  Hobart Hurricanes   1.0    1.0     0.0
#
#    Role  weight  Available  In_Team  exp_rnd_points  games_in_round
# 35   WK     1.0        0.0      1.0       55.869133             1.0
# 61  BWL     1.0        1.0      1.0       50.995424             1.0
# 89   WK     1.0        1.0      1.0       43.037401             1.0
# EFP Optimal Team Saved

# %% [markdown]
# # 2. New Distribution Approach

# %% [markdown]
# # a. Data Extraction

# %%
# New Optimisation Strategy (Player Fantasy Point Distribution)
if opt_strat == 'sim':
    # Data Extraction 
    # Pull in player price data csv file 
    price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_2026_sim_rnd_4.csv'), low_memory=False)

    # Player Role Flags
    price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
    price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 

    team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
    # team_fix_df = team_fix_df[team_fix_df.Round >= current_rnd].dropna()

    # Join team fixture to player price to create a row for each game
    game_df = pd.merge(price_df, team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")

    # Pull player expected & std points csv file
    if exp_pts_model == 'bat_bowl':
        efp_raw_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_bat_bowl_model_score_short_pr4.csv'), low_memory=False)
        sfp_df = pd.read_csv(os.path.join(py_data_score_directory,'bbl15_sfp_model_score_short_upd3.csv'), low_memory=False)
        efp_df = efp_raw_df.merge(sfp_df, left_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], right_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")

    elif exp_pts_model == 'all':
        efp_raw_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_model_score_short_pr4.csv'), low_memory=False)
        sfp_df = pd.read_csv(os.path.join(py_data_score_directory,'bbl15_sfp_model_score_short_upd3.csv'), low_memory=False)
        efp_df = efp_raw_df.merge(sfp_df, left_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], right_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")

    # # Join on expected points for each game
    player_df_raw = pd.merge(game_df, efp_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")
    player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 11.68, player_df_raw["exp_pts"] + 4.42)
    player_df_raw = player_df_raw.rename(columns={"exp_pts": "mean"})
    player_df_raw = player_df_raw.rename(columns={"sd_pts": "std_dev"})

    player_df_raw["weight"] = 1
    
    # Create game count per player
    player_df_raw["game_num"] = player_df_raw.groupby("Name").cumcount() + 1

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")

# %% [markdown]
# # b. Optimisation Process (During Tournament Selection) - Starting 12 Players
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 13 (Incl Bench Player)
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total starting budget of team is less than $15 player budget + surplass (bench costs $79,000)

# %%
# Sim FP Whole Tournament Optimisation
if opt_strat == 'sim':
    # Load Model Objects
    price_model_obj_1 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_1_game'))
    price_model_obj_2 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_2_game'))
    price_model_obj_3 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_3_game'))

    # Run Simulation Optimisation Function (with parallel execution enabled)
    all_sim_sel_players = optimise_fn_sim_fp(
        conf_int, sim_num, current_rnd, sim_budget, player_df_raw, price_df, 
        price_model_obj_1, price_model_obj_2, price_model_obj_3,
        use_parallel=True  # Set to False for sequential execution
    )

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# For 20% simulated points confidence interval the lower z score is -0.253 and upper z score is 0.253
# Completed 10/10000 simulations
# Completed 8120/10000 simulations
# Completed 8130/10000 simulations
# Completed 8140/10000 simulations
# Completed 8150/10000 simulations
# Completed 8160/10000 simulations
# Completed 8170/10000 simulations
# Completed 8180/10000 simulations
# Completed 8190/10000 simulations
# Completed 8200/10000 simulations
# Completed 8210/10000 simulations
# Completed 8220/10000 simulations
# Completed 8230/10000 simulations
# Completed 8240/10000 simulations
# Completed 8250/10000 simulations
# Completed 8260/10000 simulations
# Completed 8270/10000 simulations
# Completed 8280/10000 simulations
# Completed 8290/10000 simulations
# Completed 8300/10000 simulations
# Completed 8310/10000 simulations
# Completed 8320/10000 simulations
# Completed 8330/10000 simulations
# Completed 8340/10000 simulations
# Completed 8350/10000 simulations
# Completed 8360/10000 simulations
# Completed 8370/10000 simulations
# Completed 8380/10000 simulations
# Completed 8390/10000 simulations
# Completed 8400/10000 simulations
# Completed 8410/10000 simulations
# Completed 8420/10000 simulations
# Completed 8430/10000 simulations
# Completed 8440/10000 simulations
# Completed 8450/10000 simulations
# Completed 8460/10000 simulations
# Completed 8470/10000 simulations
# Completed 8480/10000 simulations
# Completed 8490/10000 simulations
# Completed 8500/10000 simulations
# Completed 8510/10000 simulations
# Completed 8520/10000 simulations
# Completed 8530/10000 simulations
# Completed 8540/10000 simulations
# Completed 8550/10000 simulations
# Completed 8560/10000 simulations
# Completed 8570/10000 simulations
# Completed 8580/10000 simulations
# Completed 8590/10000 simulations
# Completed 8600/10000 simulations
# Completed 8610/10000 simulations
# Completed 8620/10000 simulations
# Completed 8630/10000 simulations
# Completed 8640/10000 simulations
# Completed 8650/10000 simulations
# Completed 8660/10000 simulations
# Completed 8670/10000 simulations
# Completed 8680/10000 simulations
# Completed 8690/10000 simulations
# Completed 8700/10000 simulations
# Completed 8710/10000 simulations
# Completed 8720/10000 simulations
# Completed 8730/10000 simulations
# Completed 8740/10000 simulations
# Completed 8750/10000 simulations
# Completed 8760/10000 simulations
# Completed 8770/10000 simulations
# Completed 8780/10000 simulations
# Completed 8790/10000 simulations
# Completed 8800/10000 simulations
# Completed 8810/10000 simulations
# Completed 8820/10000 simulations
# Completed 8830/10000 simulations
# Completed 8840/10000 simulations
# Completed 8850/10000 simulations
# Completed 8860/10000 simulations
# Completed 8870/10000 simulations
# Completed 8880/10000 simulations
# Completed 8890/10000 simulations
# Completed 8900/10000 simulations
# Completed 8910/10000 simulations
# Completed 8920/10000 simulations
# Completed 8930/10000 simulations
# Completed 8940/10000 simulations
# Completed 8950/10000 simulations
# Completed 8960/10000 simulations
# Completed 8970/10000 simulations
# Completed 8980/10000 simulations
# Completed 8990/10000 simulations
# Completed 9000/10000 simulations
# Completed 9010/10000 simulations
# Completed 9020/10000 simulations
# Completed 9030/10000 simulations
# Completed 9040/10000 simulations
# Completed 9050/10000 simulations
# Completed 9060/10000 simulations
# Completed 9070/10000 simulations
# Completed 9080/10000 simulations
# Completed 9090/10000 simulations
# Completed 9100/10000 simulations
# Completed 9110/10000 simulations
# Completed 9120/10000 simulations
# Completed 9130/10000 simulations
# Completed 9140/10000 simulations
# Completed 9150/10000 simulations
# Completed 9160/10000 simulations
# Completed 9170/10000 simulations
# Completed 9180/10000 simulations
# Completed 9190/10000 simulations
# Completed 9200/10000 simulations
# Completed 9210/10000 simulations
# Completed 9220/10000 simulations
# Completed 9230/10000 simulations
# Completed 9240/10000 simulations
# Completed 9250/10000 simulations
# Completed 9260/10000 simulations
# Completed 9270/10000 simulations
# Completed 9280/10000 simulations
# Completed 9290/10000 simulations
# Completed 9300/10000 simulations
# Completed 9310/10000 simulations
# Completed 9320/10000 simulations
# Completed 9330/10000 simulations
# Completed 9340/10000 simulations
# Completed 9350/10000 simulations
# Completed 9360/10000 simulations
# Completed 9370/10000 simulations
# Completed 9380/10000 simulations
# Completed 9390/10000 simulations
# Completed 9400/10000 simulations
# Completed 9410/10000 simulations
# Completed 9420/10000 simulations
# Completed 9430/10000 simulations
# Completed 9440/10000 simulations
# Completed 9450/10000 simulations
# Completed 9460/10000 simulations
# Completed 9470/10000 simulations
# Completed 9480/10000 simulations
# Completed 9490/10000 simulations
# Completed 9500/10000 simulations
# Completed 9510/10000 simulations
# Completed 9520/10000 simulations
# Completed 9530/10000 simulations
# Completed 9540/10000 simulations
# Completed 9550/10000 simulations
# Completed 9560/10000 simulations
# Completed 9570/10000 simulations
# Completed 9580/10000 simulations
# Completed 9590/10000 simulations
# Completed 9600/10000 simulations
# Completed 9610/10000 simulations
# Completed 9620/10000 simulations
# Completed 9630/10000 simulations
# Completed 9640/10000 simulations
# Completed 9650/10000 simulations
# Completed 9660/10000 simulations
# Completed 9670/10000 simulations
# Completed 9680/10000 simulations
# Completed 9690/10000 simulations
# Completed 9700/10000 simulations
# Completed 9710/10000 simulations
# Completed 9720/10000 simulations
# Completed 9730/10000 simulations
# Completed 9740/10000 simulations
# Completed 9750/10000 simulations
# Completed 9760/10000 simulations
# Completed 9770/10000 simulations
# Completed 9780/10000 simulations
# Completed 9790/10000 simulations
# Completed 9800/10000 simulations
# Completed 9810/10000 simulations
# Completed 9820/10000 simulations
# Completed 9830/10000 simulations
# Completed 9840/10000 simulations
# Completed 9850/10000 simulations
# Completed 9860/10000 simulations
# Completed 9870/10000 simulations
# Completed 9880/10000 simulations
# Completed 9890/10000 simulations
# Completed 9900/10000 simulations
# Completed 9910/10000 simulations
# Completed 9920/10000 simulations
# Completed 9930/10000 simulations
# Completed 9940/10000 simulations
# Completed 9950/10000 simulations
# Completed 9960/10000 simulations
# Completed 9970/10000 simulations
# Completed 9980/10000 simulations
# Completed 9990/10000 simulations
# Completed 10000/10000 simulations

# %%
# Find Most Common Player Combinations Across Simulations
if opt_strat == 'sim':
    from collections import Counter
    
    # Group by simulation and create player combination sets
    sim_combinations = []
    
    for sim_id in all_sim_sel_players['Simulation'].unique():
        sim_players = all_sim_sel_players[all_sim_sel_players['Simulation'] == sim_id]['Name'].unique()
        # Create a frozenset to make it hashable for counting
        player_set = frozenset(sim_players)
        sim_combinations.append(player_set)
    
    # Count frequency of each combination
    combination_counts = Counter(sim_combinations)
    
    # Sort by frequency (descending)
    sorted_combinations = sorted(combination_counts.items(), key=lambda x: x[1], reverse=True)
    
    # Display results
    print(f"Total Unique Player Combinations: {len(combination_counts)}")
    print(f"Total Simulations: {len(sim_combinations)}\n")
    
    # Show top 10 combinations
    print("=" * 80)
    print("TOP 10 MOST COMMON PLAYER COMBINATIONS")
    print("=" * 80)
    
    for rank, (player_combo, count) in enumerate(sorted_combinations[:10], 1):
        percentage = (count / len(sim_combinations)) * 100
        print(f"\nRank {rank}: {count}/{len(sim_combinations)} simulations ({percentage:.1f}%)")
        print(f"Players: {sorted(list(player_combo))}")
        print("-" * 80)

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# Total Unique Player Combinations: 1127
# Total Simulations: 10000
#
# ================================================================================
# TOP 10 MOST COMMON PLAYER COMBINATIONS
# ================================================================================
#
# Rank 1: 392/10000 simulations (3.9%)
# Players: ['Aaron Hardie', 'Finn Allen', 'Glenn Maxwell', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Mitchell Swepson', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 2: 376/10000 simulations (3.8%)
# Players: ['Aaron Hardie', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Gurinder Sandhu', 'Haris Rauf', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Nathan Ellis', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 3: 288/10000 simulations (2.9%)
# Players: ['Aaron Hardie', 'Finn Allen', 'Glenn Maxwell', 'Gurinder Sandhu', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Mitchell Swepson', 'Nathan Ellis', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 4: 284/10000 simulations (2.8%)
# Players: ['Ben Manenti', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Haris Rauf', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Nathan Ellis', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 5: 280/10000 simulations (2.8%)
# Players: ['Aaron Hardie', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Gurinder Sandhu', 'Haris Rauf', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Nathan Ellis', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 6: 262/10000 simulations (2.6%)
# Players: ['Aaron Hardie', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Haris Rauf', 'Marcus Stoinis', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 7: 247/10000 simulations (2.5%)
# Players: ['Aaron Hardie', 'Ben Manenti', 'Finn Allen', 'Glenn Maxwell', 'Haris Rauf', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 8: 235/10000 simulations (2.4%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Haris Rauf', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Nathan Ellis', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 9: 216/10000 simulations (2.2%)
# Players: ['Ben Manenti', 'Brody Couch', 'Finn Allen', 'Glenn Maxwell', 'Haris Rauf', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Nathan Ellis', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 10: 210/10000 simulations (2.1%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Finn Allen', 'Glenn Maxwell', 'Jack Wildermuth', 'Marcus Stoinis', 'Matthew Short', 'Mitch Owen', 'Mitchell Swepson', 'Nathan Ellis', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------

# %%
# Create DataFrame Summary of Most Common Combinations
if opt_strat == 'sim':
    # Get current team players
    current_team_players = set(price_df[price_df['In_Team'] == 1]['Name'].tolist())
    
    # Create a dataframe with combination rankings
    combination_summary = []
    
    for rank, (player_combo, count) in enumerate(sorted_combinations, 1):
        percentage = (count / len(sim_combinations)) * 100
        
        # Find traded out players (in current team but not in this combination)
        traded_out_players = current_team_players - set(player_combo)
        
        # Find traded in players (in this combination but not in current team)
        traded_in_players = set(player_combo) - current_team_players
        
        combination_summary.append({
            'Rank': rank,
            'Frequency': count,
            'Percentage': f"{percentage:.1f}%",
            'Players': ', '.join(sorted(list(player_combo))),
            'Num_Players': len(player_combo),
            'Traded_In': ', '.join(sorted(list(traded_in_players))) if traded_in_players else 'None',
            'Traded_Out': ', '.join(sorted(list(traded_out_players))) if traded_out_players else 'None'
        })
    
    combination_summary_df = pd.DataFrame(combination_summary)
    
    # Display the top combinations as a nice table
    print("\nCOMBINATION SUMMARY TABLE:")
    print(combination_summary_df.head(10).to_string(index=False))
    
    # Get the most common combination
    if sorted_combinations:
        most_common_players = sorted(list(sorted_combinations[0][0]))
        most_common_count = sorted_combinations[0][1]
        most_common_percentage = (most_common_count / len(sim_combinations)) * 100
        
        print(f"\n{'='*80}")
        print(f"MOST COMMON COMBINATION SELECTED:")
        print(f"{'='*80}")
        print(f"Appears in: {most_common_count}/{len(sim_combinations)} simulations ({most_common_percentage:.1f}%)")
        print(f"\nPlayers ({len(most_common_players)}):")
        for i, player in enumerate(most_common_players, 1):
            print(f"  {i:2d}. {player}")
        print(f"{'='*80}")

    # Format most common players into dataframe
    most_common_players = pd.DataFrame(most_common_players, columns=['Name'])

    # Merge with player details
    most_common_players = pd.merge(most_common_players, price_df, on='Name', how='left')
    
    # Save Combination Summary to CSV
    if exp_pts_model == 'all':
        most_common_players.to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_team_rnd_5.csv'), index=False)
        combination_summary_df.head(5).to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_combos_rnd_5.csv'), index=False)

        print("Sim FP Combination Summary Saved")
    elif exp_pts_model == 'bat_bowl':
        most_common_players.to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_team_dual_rnd_5.csv'), index=False)
        combination_summary_df.head(5).to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_combos_dual_rnd_5.csv'), index=False)

        print("Sim FP Combination Summary Saved")

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# COMBINATION SUMMARY TABLE:
#  Rank  Frequency Percentage                                                                                                                                                                                                                        Players  Num_Players                                     Traded_In                                    Traded_Out
#     1        392       3.9%    Aaron Hardie, Finn Allen, Glenn Maxwell, Jack Wildermuth, Marcus Stoinis, Matthew Short, Matthew Wade, Mitch Owen, Mitchell Swepson, Nathan McAndrew, Peter Siddle, Riley Meredith, Sam Harper, Tom Curran, Will Sutherland           15    Mitchell Swepson, Peter Siddle, Sam Harper     Brody Couch, Mahli Beardman, Nathan Ellis
#     2        376       3.8%           Aaron Hardie, Brody Couch, Finn Allen, Glenn Maxwell, Gurinder Sandhu, Haris Rauf, Marcus Stoinis, Matthew Short, Mitch Owen, Nathan Ellis, Nathan McAndrew, Riley Meredith, Sam Harper, Tom Curran, Will Sutherland           15       Gurinder Sandhu, Haris Rauf, Sam Harper Jack Wildermuth, Mahli Beardman, Matthew Wade
#     3        288       2.9% Aaron Hardie, Finn Allen, Glenn Maxwell, Gurinder Sandhu, Jack Wildermuth, Marcus Stoinis, Matthew Short, Mitch Owen, Mitchell Swepson, Nathan Ellis, Nathan McAndrew, Riley Meredith, Sam Harper, Tom Curran, Will Sutherland           15 Gurinder Sandhu, Mitchell Swepson, Sam Harper     Brody Couch, Mahli Beardman, Matthew Wade
#     4        284       2.8%            Ben Manenti, Brody Couch, Finn Allen, Glenn Maxwell, Haris Rauf, Jack Wildermuth, Marcus Stoinis, Matthew Short, Mitch Owen, Nathan Ellis, Nathan McAndrew, Riley Meredith, Sam Harper, Tom Curran, Will Sutherland           15           Ben Manenti, Haris Rauf, Sam Harper    Aaron Hardie, Mahli Beardman, Matthew Wade
