# %% [markdown]
# # Project: BBLF AI Selector v2
# # Section: Optimisation & Simulation Tool
# # Sub Section: During Tourny (Post Rnd 5)

# %% [markdown]
# Goal: Select the optimal starting 12 players prior to the start of the tournament

# %% [markdown]
# Things to add:
# 1. Additional constraints to capture fantasy nuances e.g. captain points, vice captain trick

# %% [markdown]
# # 0. Prerequistes

# %%
# pip install --upgrade pip

# %%
# !pip install mip==1.16rc0
# !pip install mip
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 
from scipy.stats import norm
import joblib
from concurrent.futures import ProcessPoolExecutor
import warnings
warnings.filterwarnings("ignore")

# Import intermediary functions
from Optimisation_Functions import roll_rnd_price_fn, optimise_fn_efp, optimise_fn_sim_fp, optimise_setup_fn

# Set working directory
os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/add_data_created/post_round_5/'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/add_data_created/overall'
py_data_score_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/python_data/scoring'
py_data_score_rnd_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Repos/Big-Bash-Fantasy-AI-v2/data/python_data/scoring/post-round-5/'

# %%
# Optimisation Strategy
opt_strat = 'sim' # Options: 'efp' (new player expected fantasy points appraoch), 'sim' (new player fantasy point distribution approach)
current_rnd = 6 # Current Round of the Tournament
exp_pts_model = 'all' # Options: 'bat_bowl' (batting + bowling model), 'all' (combined model)
efp_budget = 2047600
sim_budget = 2030600

# Constraints
# squad_players = 15 Not required as strategy set to 15 players (following round 1 optimisation strategy)

# For Simulation Optimisation Strategy
conf_int = 0.2
sim_num = 20000

# %% [markdown]
# # 1. New EFP Approach

# %% [markdown]
# # a. Data Extraction

# %%
# New Season Optimisation Strategy (Expected Fantasy Points)
if opt_strat == 'efp':
    
    # Data Extraction 
    # Pull in player price data csv file 
    price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_2026_efp_rnd_5.csv'), low_memory=False)

    # Create Player Role Flags
    price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
    price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 

    team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
    # team_fix_df = team_fix_df[team_fix_df.Round >= current_rnd].dropna()

    # Join team fixture to player price to create a row for each game
    game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")

    # Pull player expected points csv file
    if exp_pts_model == 'bat_bowl':
        efp_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_bat_bowl_model_score_short_pr5.csv'), low_memory=False)
    elif exp_pts_model == 'all':
        efp_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_model_score_short_pr5.csv'), low_memory=False)

    # Join on expected points for each game
    player_df_raw = pd.merge(game_df, efp_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")
    # If pts_type is exp then add fielding points to expected points
    player_df_raw["exp_points"] = np.where((player_df_raw["Role"] == "WK") & (player_df_raw["pts_type"] == "exp"), player_df_raw["exp_pts"] + 11.68,
                                           np.where((player_df_raw["pts_type"] == "exp"), player_df_raw["exp_pts"] + 4.42, player_df_raw["exp_pts"]))
    
    # Drop unnecessary columns
    player_df_raw = player_df_raw[["Name", "Team", "Role", "Price", "Wk_f", "Bat_f", "Bowl_f", "Available", "In_Team", "Round", "opp", "venue", "Home_f", "exp_points"]]
    player_df_raw["weight"] = 1

    # Create game count per player
    player_df_raw["game_num"] = player_df_raw.groupby("Name").cumcount() + 1
    
else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Change opt_strat to efp for player efp Optimisation Strategy

# %% [markdown]
# # b. Player price prediction for each round & data prep for optimisation

# %%
if opt_strat == 'efp':
    # Incorporate Player Actual Points into dataframes used for pricing model

    
    # Import Pricing Models
    # Load Model Objects
    price_model_obj_1 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_1_game'))
    price_model_obj_2 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_2_game'))
    price_model_obj_3 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_3_game'))

    # Create rolling round player price dataframes
    player_df_r1, player_df_r2, player_df_r3, player_df_r4, player_df_r5, player_df_r6, player_df_r7, player_df_r8, player_df_r9 = roll_rnd_price_fn(player_df_raw, price_df, current_rnd, price_model_obj_1, price_model_obj_2, price_model_obj_3)

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Change opt_strat to efp for player efp Optimisation Strategy

# %% [markdown]
# # c. Optimisation Process (During Tournament Selection) - Starting 12 + 3 Bench Players
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12 + 3 bench player
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,802,500 (As bench costs $79,000)

# %% [markdown]
# ## Optimisation Setup

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    # a. EFP Optimisation Variables Setup
    # points_r1, price_r1, weight_r1, in_team_r1, available_r1, wk_weight_r1, bat_weight_r1, bowl_weight_r1, \
    #     play_cnt_r1, total_player_r1, wk_cnt_r1, total_wk_r1, bat_cnt_r1, total_bat_r1, bowl_cnt_r1, total_bowl_r1, \
    #     budget_r1, total_budget_r1, player_df_r1, cnt_r1, max_player_r1, \
    # points_r2, price_r2, weight_r2, in_team_r2, available_r2, wk_weight_r2, bat_weight_r2, bowl_weight_r2, \
    # play_cnt_r2, total_player_r2, wk_cnt_r2, total_wk_r2, bat_cnt_r2, total_bat_r2, bowl_cnt_r2, total_bowl_r2, \
    # budget_r2, total_budget_r2, team_play_cnt_r2, total_team_player_r2, player_df_r2, cnt_r2, max_player_r2, \
    # points_r3, price_r3, weight_r3, in_team_r3, available_r3, wk_weight_r3, bat_weight_r3, bowl_weight_r3, \
    # play_cnt_r3, total_player_r3, wk_cnt_r3, total_wk_r3, bat_cnt_r3, total_bat_r3, bowl_cnt_r3, total_bowl_r3, \
    # budget_r3, total_budget_r3, team_play_cnt_r3, total_team_player_r3, player_df_r3, cnt_r3, max_player_r3, \
    # points_r4, price_r4, weight_r4, in_team_r4, available_r4, wk_weight_r4, bat_weight_r4, bowl_weight_r4, \
    # play_cnt_r4, total_player_r4, wk_cnt_r4, total_wk_r4, bat_cnt_r4, total_bat_r4, bowl_cnt_r4, total_bowl_r4, \
    # budget_r4, total_budget_r4, team_play_cnt_r4, total_team_player_r4, player_df_r4, cnt_r4, max_player_r4, \
    # points_r5, price_r5, weight_r5, in_team_r5, available_r5, wk_weight_r5, bat_weight_r5, bowl_weight_r5, \
    # play_cnt_r5, total_player_r5, wk_cnt_r5, total_wk_r5, bat_cnt_r5, total_bat_r5, bowl_cnt_r5, total_bowl_r5, \
    # budget_r5, total_budget_r5, team_play_cnt_r5, total_team_player_r5, player_df_r5, cnt_r5, max_player_r5, \
    points_r6, price_r6, weight_r6, in_team_r6, available_r6, wk_weight_r6, bat_weight_r6, bowl_weight_r6, \
    play_cnt_r6, total_player_r6, wk_cnt_r6, total_wk_r6, bat_cnt_r6, total_bat_r6, bowl_cnt_r6, total_bowl_r6, \
    budget_r6, total_budget_r6, team_play_cnt_r6, total_team_player_r6, player_df_r6, cnt_r6, max_player_r6, \
    points_r7, price_r7, weight_r7, in_team_r7, available_r7, wk_weight_r7, bat_weight_r7, bowl_weight_r7, \
    play_cnt_r7, total_player_r7, wk_cnt_r7, total_wk_r7, bat_cnt_r7, total_bat_r7, bowl_cnt_r7, total_bowl_r7, \
    budget_r7, total_budget_r7, team_play_cnt_r7, total_team_player_r7, player_df_r7, cnt_r7, max_player_r7, \
    points_r8, price_r8, weight_r8, in_team_r8, available_r8, wk_weight_r8, bat_weight_r8, bowl_weight_r8, \
    play_cnt_r8, total_player_r8, wk_cnt_r8, total_wk_r8, bat_cnt_r8, total_bat_r8, bowl_cnt_r8, total_bowl_r8, \
    budget_r8, total_budget_r8, team_play_cnt_r8, total_team_player_r8, player_df_r8, cnt_r8, max_player_r8, \
    points_r9, price_r9, weight_r9, in_team_r9, available_r9, wk_weight_r9, bat_weight_r9, bowl_weight_r9, \
    play_cnt_r9, total_player_r9, wk_cnt_r9, total_wk_r9, bat_cnt_r9, total_bat_r9, bowl_cnt_r9, total_bowl_r9, \
    budget_r9, total_budget_r9, team_play_cnt_r9, total_team_player_r9, player_df_r9, cnt_r9, max_player_r9 =  optimise_setup_fn(
        player_df_r6, player_df_r7, player_df_r8, player_df_r9, efp_budget)

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Change opt_strat to efp for player efp Optimisation Strategy

# %% [markdown]
# ## Optimisation Runner

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    sel_player_df, sel_player_df_r6, sel_player_df_r7,sel_player_df_r8, sel_player_df_r9 = optimise_fn_efp(
        # Round 1
        # points_r1, price_r1, weight_r1, in_team_r1, available_r1, wk_weight_r1, bat_weight_r1, bowl_weight_r1,
        # play_cnt_r1, total_player_r1, wk_cnt_r1, total_wk_r1, bat_cnt_r1, total_bat_r1, bowl_cnt_r1, total_bowl_r1,
        # budget_r1, total_budget_r1, player_df_r1, cnt_r1, max_player_r1,
        # Round 2
        # points_r2, price_r2, weight_r2, in_team_r2, available_r2, wk_weight_r2, bat_weight_r2, bowl_weight_r2,
        # play_cnt_r2, total_player_r2, wk_cnt_r2, total_wk_r2, bat_cnt_r2, total_bat_r2, bowl_cnt_r2, total_bowl_r2,
        # budget_r2, total_budget_r2, team_play_cnt_r2, total_team_player_r2, player_df_r2, cnt_r2, max_player_r2,
        # Round 3
        # points_r3, price_r3, weight_r3, in_team_r3, available_r3, wk_weight_r3, bat_weight_r3, bowl_weight_r3,
        # play_cnt_r3, total_player_r3, wk_cnt_r3, total_wk_r3, bat_cnt_r3, total_bat_r3, bowl_cnt_r3, total_bowl_r3,
        # budget_r3, total_budget_r3, team_play_cnt_r3, total_team_player_r3, player_df_r3, cnt_r3, max_player_r3,
        # Round 4
        # points_r4, price_r4, weight_r4, in_team_r4, available_r4, wk_weight_r4, bat_weight_r4, bowl_weight_r4,
        # play_cnt_r4, total_player_r4, wk_cnt_r4, total_wk_r4, bat_cnt_r4, total_bat_r4, bowl_cnt_r4, total_bowl_r4,
        # budget_r4, total_budget_r4, team_play_cnt_r4, total_team_player_r4, player_df_r4, cnt_r4, max_player_r4,
        # Round 5
        # points_r5, price_r5, weight_r5, in_team_r5, available_r5, wk_weight_r5, bat_weight_r5, bowl_weight_r5,
        # play_cnt_r5, total_player_r5, wk_cnt_r5, total_wk_r5, bat_cnt_r5, total_bat_r5, bowl_cnt_r5, total_bowl_r5,
        # budget_r5, total_budget_r5, team_play_cnt_r5, total_team_player_r5, player_df_r5, cnt_r5, max_player_r5,
        # Round 6
        points_r6, price_r6, weight_r6, in_team_r6, available_r6, wk_weight_r6, bat_weight_r6, bowl_weight_r6,
        play_cnt_r6, total_player_r6, wk_cnt_r6, total_wk_r6, bat_cnt_r6, total_bat_r6, bowl_cnt_r6, total_bowl_r6,
        budget_r6, total_budget_r6, team_play_cnt_r6, total_team_player_r6, player_df_r6, cnt_r6, max_player_r6,
        # Round 7
        points_r7, price_r7, weight_r7, in_team_r7, available_r7, wk_weight_r7, bat_weight_r7, bowl_weight_r7,
        play_cnt_r7, total_player_r7, wk_cnt_r7, total_wk_r7, bat_cnt_r7, total_bat_r7, bowl_cnt_r7, total_bowl_r7,
        budget_r7, total_budget_r7, team_play_cnt_r7, total_team_player_r7, player_df_r7, cnt_r7, max_player_r7,
        # Round 8
        points_r8, price_r8, weight_r8, in_team_r8, available_r8, wk_weight_r8, bat_weight_r8, bowl_weight_r8,
        play_cnt_r8, total_player_r8, wk_cnt_r8, total_wk_r8, bat_cnt_r8, total_bat_r8, bowl_cnt_r8, total_bowl_r8,
        budget_r8, total_budget_r8, team_play_cnt_r8, total_team_player_r8, player_df_r8, cnt_r8, max_player_r8,
        # Round 9
        points_r9, price_r9, weight_r9, in_team_r9, available_r9, wk_weight_r9, bat_weight_r9, bowl_weight_r9,
        play_cnt_r9, total_player_r9, wk_cnt_r9, total_wk_r9, bat_cnt_r9, total_bat_r9, bowl_cnt_r9, total_bowl_r9,
        budget_r9, total_budget_r9, team_play_cnt_r9, total_team_player_r9, player_df_r9, cnt_r9, max_player_r9
    )

else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Change opt_strat to efp for player efp Optimisation Strategy

# %% [markdown]
# ## Optimisation Results

# %%
# EFP Whole Tournament Optimisation
if opt_strat == 'efp':
    # Display Round-wise Selected Teams
    print("Round 6 Selected Team")
    display(sel_player_df_r6.sort_values(by='exp_rnd_points', ascending=False))

    # Display Traded In Players
    traded_in_r6 = sel_player_df_r6[sel_player_df_r6['In_Team'] == 0]
    print("Round 6 Traded In Players")
    display(traded_in_r6.sort_values(by='exp_rnd_points', ascending=False))

    # Display Traded Out Players
    traded_out_r6 = player_df_r6[player_df_r6['In_Team'] == 1][~player_df_r6['Name'].isin(sel_player_df_r6['Name'])].drop_duplicates(subset=['Name'])
    print("Round 6 Traded Out Players")
    display(traded_out_r6.sort_values(by='exp_rnd_points', ascending=False))

    # Save Optimal Team to CSV
    if exp_pts_model == 'all':
        sel_player_df.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_rnd_6.csv'), index=False)
        sel_player_df_r6.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_round_rnd_6.csv'), index=False)
        print("EFP Optimal Team Saved")
    elif exp_pts_model == 'bat_bowl':
        sel_player_df.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_dual_rnd_6.csv'), index=False)
        sel_player_df_r6.to_csv(os.path.join(add_data_directory,'optim/EFP_optimal_team_dual_round_rnd_6.csv'), index=False)
        print("EFP Bat + Bowl Optimal Team Saved")
else:
    print("Change opt_strat to efp for player efp Optimisation Strategy")
# Out:
# Change opt_strat to efp for player efp Optimisation Strategy

# %% [markdown]
# # 2. New Distribution Approach

# %% [markdown]
# # a. Data Extraction

# %%
# New Optimisation Strategy (Player Fantasy Point Distribution)
if opt_strat == 'sim':
    # Data Extraction 
    # Pull in player price data csv file 
    price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_2026_sim_rnd_5.csv'), low_memory=False)

    # Player Role Flags
    price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
    price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
    price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 

    team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
    # team_fix_df = team_fix_df[team_fix_df.Round >= current_rnd].dropna()

    # Join team fixture to player price to create a row for each game
    game_df = pd.merge(price_df, team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")

    # Pull player expected & std points csv file
    if exp_pts_model == 'bat_bowl':
        efp_raw_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_bat_bowl_model_score_short_pr5.csv'), low_memory=False)
        sfp_df = pd.read_csv(os.path.join(py_data_score_directory,'bbl15_sfp_model_score_short_upd3.csv'), low_memory=False)
        efp_df = efp_raw_df.merge(sfp_df, left_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], right_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")

    elif exp_pts_model == 'all':
        efp_raw_df = pd.read_csv(os.path.join(py_data_score_rnd_directory,'bbl15_efp_model_score_short_pr5.csv'), low_memory=False)
        sfp_df = pd.read_csv(os.path.join(py_data_score_directory,'bbl15_sfp_model_score_short_upd3.csv'), low_memory=False)
        efp_df = efp_raw_df.merge(sfp_df, left_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], right_on = ["player", "Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")

    # # Join on expected points for each game
    player_df_raw = pd.merge(game_df, efp_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")
    player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 11.68, player_df_raw["exp_pts"] + 4.42)
    player_df_raw = player_df_raw.rename(columns={"exp_pts": "mean"})
    player_df_raw = player_df_raw.rename(columns={"sd_pts": "std_dev"})

    player_df_raw["weight"] = 1
    
    # Create game count per player
    player_df_raw["game_num"] = player_df_raw.groupby("Name").cumcount() + 1

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")

# %% [markdown]
# # b. Optimisation Process (During Tournament Selection) - Starting 12 Players
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 13 (Incl Bench Player)
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total starting budget of team is less than $15 player budget + surplass (bench costs $79,000)

# %%
# Sim FP Whole Tournament Optimisation
if opt_strat == 'sim':
    # Load Model Objects
    price_model_obj_1 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_1_game'))
    price_model_obj_2 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_2_game'))
    price_model_obj_3 = joblib.load(os.path.join(directory, 'python_script/pricing-models/models/bbl15_price_model_3_game'))

    # Run Simulation Optimisation Function (with parallel execution enabled)
    all_sim_sel_players = optimise_fn_sim_fp(
        conf_int, sim_num, current_rnd, sim_budget, player_df_raw, price_df, 
        price_model_obj_1, price_model_obj_2, price_model_obj_3,
        use_parallel=True  # Set to False for sequential execution
    )

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# For 20% simulated points confidence interval the lower z score is -0.253 and upper z score is 0.253
# Completed 10/20000 simulations
# Completed 20/20000 simulations
# Completed 30/20000 simulations
# Completed 40/20000 simulations
# Completed 50/20000 simulations
# Completed 60/20000 simulations
# Completed 70/20000 simulations
# Completed 80/20000 simulations
# Completed 90/20000 simulations
# Completed 100/20000 simulations
# Completed 110/20000 simulations
# Completed 120/20000 simulations
# Completed 130/20000 simulations
# Completed 140/20000 simulations
# Completed 150/20000 simulations
# Completed 160/20000 simulations
# Completed 170/20000 simulations
# Completed 180/20000 simulations
# Completed 190/20000 simulations
# Completed 200/20000 simulations
# Completed 210/20000 simulations
# Completed 220/20000 simulations
# Completed 230/20000 simulations
# Completed 240/20000 simulations
# Completed 250/20000 simulations
# Completed 260/20000 simulations
# Completed 270/20000 simulations
# Completed 280/20000 simulations
# Completed 290/20000 simulations
# Completed 300/20000 simulations
# Completed 310/20000 simulations
# Completed 320/20000 simulations
# Completed 330/20000 simulations
# Completed 340/20000 simulations
# Completed 350/20000 simulations
# Completed 360/20000 simulations
# Completed 370/20000 simulations
# Completed 380/20000 simulations
# Completed 390/20000 simulations
# Completed 400/20000 simulations
# Completed 410/20000 simulations
# Completed 420/20000 simulations
# Completed 430/20000 simulations
# Completed 440/20000 simulations
# Completed 450/20000 simulations
# Completed 460/20000 simulations
# Completed 470/20000 simulations
# Completed 480/20000 simulations
# Completed 490/20000 simulations
# Completed 500/20000 simulations
# Completed 510/20000 simulations
# Completed 520/20000 simulations
# Completed 530/20000 simulations
# Completed 540/20000 simulations
# Completed 550/20000 simulations
# Completed 560/20000 simulations
# Completed 570/20000 simulations
# Completed 580/20000 simulations
# Completed 590/20000 simulations
# Completed 600/20000 simulations
# Completed 610/20000 simulations
# Completed 620/20000 simulations
# Completed 630/20000 simulations
# Completed 640/20000 simulations
# Completed 650/20000 simulations
# Completed 660/20000 simulations
# Completed 670/20000 simulations
# Completed 680/20000 simulations
# Completed 690/20000 simulations
# Completed 700/20000 simulations
# Completed 710/20000 simulations
# Completed 720/20000 simulations
# Completed 730/20000 simulations
# Completed 740/20000 simulations
# Completed 750/20000 simulations
# Completed 760/20000 simulations
# Completed 770/20000 simulations
# Completed 780/20000 simulations
# Completed 790/20000 simulations
# Completed 800/20000 simulations
# Completed 810/20000 simulations
# Completed 820/20000 simulations
# Completed 8020/20000 simulations
# Completed 8030/20000 simulations
# Completed 8040/20000 simulations
# Completed 8050/20000 simulations
# Completed 8060/20000 simulations
# Completed 8070/20000 simulations
# Completed 8080/20000 simulations
# Completed 8090/20000 simulations
# Completed 8100/20000 simulations
# Completed 8110/20000 simulations
# Completed 8120/20000 simulations
# Completed 8130/20000 simulations
# Completed 8140/20000 simulations
# Completed 8150/20000 simulations
# Completed 8160/20000 simulations
# Completed 8170/20000 simulations
# Completed 8180/20000 simulations
# Completed 8190/20000 simulations
# Completed 8200/20000 simulations
# Completed 8210/20000 simulations
# Completed 8220/20000 simulations
# Completed 8230/20000 simulations
# Completed 8240/20000 simulations
# Completed 8250/20000 simulations
# Completed 8260/20000 simulations
# Completed 8270/20000 simulations
# Completed 8280/20000 simulations
# Completed 8290/20000 simulations
# Completed 8300/20000 simulations
# Completed 8310/20000 simulations
# Completed 8320/20000 simulations
# Completed 8330/20000 simulations
# Completed 8340/20000 simulations
# Completed 8350/20000 simulations
# Completed 8360/20000 simulations
# Completed 8370/20000 simulations
# Completed 8380/20000 simulations
# Completed 8390/20000 simulations
# Completed 8400/20000 simulations
# Completed 8410/20000 simulations
# Completed 8420/20000 simulations
# Completed 8430/20000 simulations
# Completed 8440/20000 simulations
# Completed 8450/20000 simulations
# Completed 8460/20000 simulations
# Completed 8470/20000 simulations
# Completed 8480/20000 simulations
# Completed 8490/20000 simulations
# Completed 8500/20000 simulations
# Completed 8510/20000 simulations
# Completed 8520/20000 simulations
# Completed 8530/20000 simulations
# Completed 8540/20000 simulations
# Completed 8550/20000 simulations
# Completed 8560/20000 simulations
# Completed 8570/20000 simulations
# Completed 8580/20000 simulations
# Completed 8590/20000 simulations
# Completed 8600/20000 simulations
# Completed 8610/20000 simulations
# Completed 8620/20000 simulations
# Completed 8630/20000 simulations
# Completed 8640/20000 simulations
# Completed 8650/20000 simulations
# Completed 8660/20000 simulations
# Completed 8670/20000 simulations
# Completed 8680/20000 simulations
# Completed 8690/20000 simulations
# Completed 8700/20000 simulations
# Completed 8710/20000 simulations
# Completed 8720/20000 simulations
# Completed 8730/20000 simulations
# Completed 8740/20000 simulations
# Completed 8750/20000 simulations
# Completed 8760/20000 simulations
# Completed 8770/20000 simulations
# Completed 8780/20000 simulations
# Completed 8790/20000 simulations
# Completed 8800/20000 simulations
# Completed 8810/20000 simulations
# Completed 8820/20000 simulations
# Completed 8830/20000 simulations
# Completed 8840/20000 simulations
# Completed 8850/20000 simulations
# Completed 8860/20000 simulations
# Completed 8870/20000 simulations
# Completed 8880/20000 simulations
# Completed 8890/20000 simulations
# Completed 8900/20000 simulations
# Completed 8910/20000 simulations
# Completed 8920/20000 simulations
# Completed 8930/20000 simulations
# Completed 8940/20000 simulations
# Completed 8950/20000 simulations
# Completed 8960/20000 simulations
# Completed 8970/20000 simulations
# Completed 8980/20000 simulations
# Completed 8990/20000 simulations
# Completed 9000/20000 simulations
# Completed 9010/20000 simulations
# Completed 9020/20000 simulations
# Completed 9030/20000 simulations
# Completed 9040/20000 simulations
# Completed 19170/20000 simulations
# Completed 19180/20000 simulations
# Completed 19190/20000 simulations
# Completed 19200/20000 simulations
# Completed 19210/20000 simulations
# Completed 19220/20000 simulations
# Completed 19230/20000 simulations
# Completed 19240/20000 simulations
# Completed 19250/20000 simulations
# Completed 19260/20000 simulations
# Completed 19270/20000 simulations
# Completed 19280/20000 simulations
# Completed 19290/20000 simulations
# Completed 19300/20000 simulations
# Completed 19310/20000 simulations
# Completed 19320/20000 simulations
# Completed 19330/20000 simulations
# Completed 19340/20000 simulations
# Completed 19350/20000 simulations
# Completed 19360/20000 simulations
# Completed 19370/20000 simulations
# Completed 19380/20000 simulations
# Completed 19390/20000 simulations
# Completed 19400/20000 simulations
# Completed 19410/20000 simulations
# Completed 19420/20000 simulations
# Completed 19430/20000 simulations
# Completed 19440/20000 simulations
# Completed 19450/20000 simulations
# Completed 19460/20000 simulations
# Completed 19470/20000 simulations
# Completed 19480/20000 simulations
# Completed 19490/20000 simulations
# Completed 19500/20000 simulations
# Completed 19510/20000 simulations
# Completed 19520/20000 simulations
# Completed 19530/20000 simulations
# Completed 19540/20000 simulations
# Completed 19550/20000 simulations
# Completed 19560/20000 simulations
# Completed 19570/20000 simulations
# Completed 19580/20000 simulations
# Completed 19590/20000 simulations
# Completed 19600/20000 simulations
# Completed 19610/20000 simulations
# Completed 19620/20000 simulations
# Completed 19630/20000 simulations
# Completed 19640/20000 simulations
# Completed 19650/20000 simulations
# Completed 19660/20000 simulations
# Completed 19670/20000 simulations
# Completed 19680/20000 simulations
# Completed 19690/20000 simulations
# Completed 19700/20000 simulations
# Completed 19710/20000 simulations
# Completed 19720/20000 simulations
# Completed 19730/20000 simulations
# Completed 19740/20000 simulations
# Completed 19750/20000 simulations
# Completed 19760/20000 simulations
# Completed 19770/20000 simulations
# Completed 19780/20000 simulations
# Completed 19790/20000 simulations
# Completed 19800/20000 simulations
# Completed 19810/20000 simulations
# Completed 19820/20000 simulations
# Completed 19830/20000 simulations
# Completed 19840/20000 simulations
# Completed 19850/20000 simulations
# Completed 19860/20000 simulations
# Completed 19870/20000 simulations
# Completed 19880/20000 simulations
# Completed 19890/20000 simulations
# Completed 19900/20000 simulations
# Completed 19910/20000 simulations
# Completed 19920/20000 simulations
# Completed 19930/20000 simulations
# Completed 19940/20000 simulations
# Completed 19950/20000 simulations
# Completed 19960/20000 simulations
# Completed 19970/20000 simulations
# Completed 19980/20000 simulations
# Completed 19990/20000 simulations
# Completed 20000/20000 simulations

# %%
# Find Most Common Player Combinations Across Simulations
if opt_strat == 'sim':
    from collections import Counter
    
    # Group by simulation and create player combination sets
    sim_combinations = []
    
    for sim_id in all_sim_sel_players['Simulation'].unique():
        sim_players = all_sim_sel_players[all_sim_sel_players['Simulation'] == sim_id]['Name'].unique()
        # Create a frozenset to make it hashable for counting
        player_set = frozenset(sim_players)
        sim_combinations.append(player_set)
    
    # Count frequency of each combination
    combination_counts = Counter(sim_combinations)
    
    # Sort by frequency (descending)
    sorted_combinations = sorted(combination_counts.items(), key=lambda x: x[1], reverse=True)
    
    # Display results
    print(f"Total Unique Player Combinations: {len(combination_counts)}")
    print(f"Total Simulations: {len(sim_combinations)}\n")
    
    # Show top 10 combinations
    print("=" * 80)
    print("TOP 10 MOST COMMON PLAYER COMBINATIONS")
    print("=" * 80)
    
    for rank, (player_combo, count) in enumerate(sorted_combinations[:10], 1):
        percentage = (count / len(sim_combinations)) * 100
        print(f"\nRank {rank}: {count}/{len(sim_combinations)} simulations ({percentage:.1f}%)")
        print(f"Players: {sorted(list(player_combo))}")
        print("-" * 80)

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# Total Unique Player Combinations: 1128
# Total Simulations: 20000
#
# ================================================================================
# TOP 10 MOST COMMON PLAYER COMBINATIONS
# ================================================================================
#
# Rank 1: 960/20000 simulations (4.8%)
# Players: ['Babar Azam', 'Ben Dwarshuis', 'Glenn Maxwell', 'Jack Wildermuth', 'Jamie Overton', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 2: 911/20000 simulations (4.6%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Glenn Maxwell', 'Hayden Kerr', 'Jack Wildermuth', 'Jamie Overton', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 3: 656/20000 simulations (3.3%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Glenn Maxwell', 'Gurinder Sandhu', 'Jack Wildermuth', 'Josh Philippe', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 4: 516/20000 simulations (2.6%)
# Players: ['Ben Dwarshuis', 'Glenn Maxwell', 'Hayden Kerr', 'Jack Wildermuth', 'Jamie Overton', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Peter Siddle', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 5: 491/20000 simulations (2.5%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Glenn Maxwell', 'Jack Wildermuth', 'Joel Davies', 'Luke Wood', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 6: 419/20000 simulations (2.1%)
# Players: ['Aaron Hardie', 'Babar Azam', 'Ben Dwarshuis', 'Glenn Maxwell', 'Jack Wildermuth', 'Luke Wood', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 7: 395/20000 simulations (2.0%)
# Players: ['Ben Dwarshuis', 'Glenn Maxwell', 'Gurinder Sandhu', 'Jack Edwards', 'Jack Wildermuth', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Mitchell Swepson', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 8: 347/20000 simulations (1.7%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Glenn Maxwell', 'Gurinder Sandhu', 'Jack Wildermuth', 'Joel Davies', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 9: 306/20000 simulations (1.5%)
# Players: ['Aaron Hardie', 'Ben Dwarshuis', 'Glenn Maxwell', 'Jack Wildermuth', 'Jamie Overton', 'Josh Philippe', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Mitchell Swepson', 'Nathan McAndrew', 'Riley Meredith', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------
#
# Rank 10: 284/20000 simulations (1.4%)
# Players: ['Aaron Hardie', 'Babar Azam', 'Ben Dwarshuis', 'Glenn Maxwell', 'Gurinder Sandhu', 'Jack Wildermuth', 'Matthew Short', 'Matthew Wade', 'Mitch Owen', 'Nathan McAndrew', 'Riley Meredith', 'Sam Harper', 'Sean Abbott', 'Tom Curran', 'Will Sutherland']
# --------------------------------------------------------------------------------

# %%
# Create DataFrame Summary of Most Common Combinations
if opt_strat == 'sim':
    # Get current team players
    current_team_players = set(price_df[price_df['In_Team'] == 1]['Name'].tolist())
    
    # Create a dataframe with combination rankings
    combination_summary = []
    
    for rank, (player_combo, count) in enumerate(sorted_combinations, 1):
        percentage = (count / len(sim_combinations)) * 100
        
        # Find traded out players (in current team but not in this combination)
        traded_out_players = current_team_players - set(player_combo)
        
        # Find traded in players (in this combination but not in current team)
        traded_in_players = set(player_combo) - current_team_players
        
        combination_summary.append({
            'Rank': rank,
            'Frequency': count,
            'Percentage': f"{percentage:.1f}%",
            'Players': ', '.join(sorted(list(player_combo))),
            'Num_Players': len(player_combo),
            'Traded_In': ', '.join(sorted(list(traded_in_players))) if traded_in_players else 'None',
            'Traded_Out': ', '.join(sorted(list(traded_out_players))) if traded_out_players else 'None'
        })
    
    combination_summary_df = pd.DataFrame(combination_summary)
    
    # Display the top combinations as a nice table
    print("\nCOMBINATION SUMMARY TABLE:")
    print(combination_summary_df.head(10).to_string(index=False))
    
    # Get the most common combination
    if sorted_combinations:
        most_common_players = sorted(list(sorted_combinations[0][0]))
        most_common_count = sorted_combinations[0][1]
        most_common_percentage = (most_common_count / len(sim_combinations)) * 100
        
        print(f"\n{'='*80}")
        print(f"MOST COMMON COMBINATION SELECTED:")
        print(f"{'='*80}")
        print(f"Appears in: {most_common_count}/{len(sim_combinations)} simulations ({most_common_percentage:.1f}%)")
        print(f"\nPlayers ({len(most_common_players)}):")
        for i, player in enumerate(most_common_players, 1):
            print(f"  {i:2d}. {player}")
        print(f"{'='*80}")

    # Format most common players into dataframe
    most_common_players = pd.DataFrame(most_common_players, columns=['Name'])

    # Merge with player details
    most_common_players = pd.merge(most_common_players, price_df, on='Name', how='left')
    
    # Save Combination Summary to CSV
    if exp_pts_model == 'all':
        most_common_players.to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_team_rnd_6.csv'), index=False)
        combination_summary_df.head(5).to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_combos_rnd_6.csv'), index=False)

        print("Sim FP Combination Summary Saved")
    elif exp_pts_model == 'bat_bowl':
        most_common_players.to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_team_dual_rnd_6.csv'), index=False)
        combination_summary_df.head(5).to_csv(os.path.join(add_data_directory,'optim/SFP_optimal_combos_dual_rnd_6.csv'), index=False)

        print("Sim FP Combination Summary Saved")

else:
    print("Change opt_strat to sim for player fp distribution Optimisation Strategy")
# Out:
# COMBINATION SUMMARY TABLE:
#  Rank  Frequency Percentage                                                                                                                                                                                                                         Players  Num_Players                                                  Traded_In                                                  Traded_Out
#     1        960       4.8%          Babar Azam, Ben Dwarshuis, Glenn Maxwell, Jack Wildermuth, Jamie Overton, Matthew Short, Matthew Wade, Mitch Owen, Nathan McAndrew, Peter Siddle, Riley Meredith, Sam Harper, Sean Abbott, Tom Curran, Will Sutherland           15      Babar Azam, Ben Dwarshuis, Jamie Overton, Sean Abbott Aaron Hardie, Brody Couch, Marcus Stoinis, Mitchell Swepson
#     2        911       4.6%         Aaron Hardie, Ben Dwarshuis, Glenn Maxwell, Hayden Kerr, Jack Wildermuth, Jamie Overton, Matthew Short, Matthew Wade, Mitch Owen, Nathan McAndrew, Riley Meredith, Sam Harper, Sean Abbott, Tom Curran, Will Sutherland           15     Ben Dwarshuis, Hayden Kerr, Jamie Overton, Sean Abbott Brody Couch, Marcus Stoinis, Mitchell Swepson, Peter Siddle
#     3        656       3.3%   Aaron Hardie, Ben Dwarshuis, Glenn Maxwell, Gurinder Sandhu, Jack Wildermuth, Josh Philippe, Matthew Short, Matthew Wade, Mitch Owen, Nathan McAndrew, Peter Siddle, Riley Meredith, Sean Abbott, Tom Curran, Will Sutherland           15 Ben Dwarshuis, Gurinder Sandhu, Josh Philippe, Sean Abbott   Brody Couch, Marcus Stoinis, Mitchell Swepson, Sam Harper
#     4        516       2.6%         Ben Dwarshuis, Glenn Maxwell, Hayden Kerr, Jack Wildermuth, Jamie Overton, Matthew Short, Matthew Wade, Mitch Owen, Nathan McAndrew, Peter Siddle, Riley Meredith, Sam Harper, Sean Abbott, Tom Curran, Will Sutherland           15     Ben Dwarshuis, Hayden Kerr, Jamie Overton, Sean Abbott Aaron Hardie, Brody Couch, Marcus Stoinis, Mitchell Swepson
